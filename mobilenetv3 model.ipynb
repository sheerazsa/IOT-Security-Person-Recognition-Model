# %%
from google.colab import drive
drive.mount('/content/drive')

import os

base_path = "/content/drive/MyDrive/Dataset"
quannene_training_path = os.path.join(base_path, "training")
quannene_testting_path = os.path.join(base_path, "testing")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Lambda, Flatten, Dense
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
K.set_image_data_format('channels_last')
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import PIL

# %% [markdown]
# MOBILENETV3 LARGE (DONT RUN)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, applications
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
import os
import random
from PIL import Image
from tensorflow.keras.layers import Layer # Moved this import to the top

# -----------------------------
# CONFIGURATION
# -----------------------------
EMBEDDING_DIM = 16
TRIPLET_LOSS_MARGIN = 0.5
IMAGE_SIZE = 224
BATCH_SIZE = 16
LEARNING_RATE = 1e-4
EPOCHS = 8
TRAIN_DATA_PATH = '/content/drive/MyDrive/Dataset/training/dataset'

# -----------------------------
# 1. DATASET: ONLINE TRIPLET GENERATOR
# -----------------------------
class TripletFaceDataset(tf.keras.utils.Sequence):
    """Generate Anchor-Positive-Negative triplets on the fly."""

    def __init__(self, root_dir, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, samples_per_epoch=1000, **kwargs):
        super().__init__(**kwargs) # Modified to pass **kwargs to address UserWarning
        self.root_dir = root_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.samples_per_epoch = samples_per_epoch

        # Map identity -> image paths
        self.identities = []
        self.identity_to_paths = {}
        for person_name in os.listdir(root_dir):
            person_path = os.path.join(root_dir, person_name)
            if os.path.isdir(person_path):
                image_paths = [os.path.join(person_path, f)
                               for f in os.listdir(person_path) # Added 'in os.listdir(person_path)'
                               if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                if len(image_paths) >= 2:
                    self.identities.append(person_name)
                    self.identity_to_paths[person_name] = image_paths

        if len(self.identities) < 2:
            raise ValueError("Need at least 2 identities with 2+ images each.")

    def __len__(self):
        return self.samples_per_epoch // self.batch_size

    def __getitem__(self, idx):
        anchors = []
        positives = []
        negatives = []

        for _ in range(self.batch_size):
            # Anchor identity
            identity_A = random.choice(self.identities)
            A_paths = self.identity_to_paths[identity_A]
            A_path, P_path = random.sample(A_paths, 2)

            # Negative identity
            identity_N = random.choice([i for i in self.identities if i != identity_A])
            N_paths = self.identity_to_paths[identity_N]
            N_path = random.choice(N_paths)

            # Load and preprocess images
            A_img = self.load_image(A_path)
            P_img = self.load_image(P_path)
            N_img = self.load_image(N_path)

            anchors.append(A_img)
            positives.append(P_img)
            negatives.append(N_img)

        return (np.array(anchors), np.array(positives), np.array(negatives)), np.zeros((self.batch_size,))

    def load_image(self, path):
        img = Image.open(path).convert('RGB').resize((self.image_size, self.image_size))
        img_array = np.array(img) / 255.0  # Normalize to [0,1]
        return img_array


# -----------------------------
# 2. BUILD EMBEDDING MODEL
# -----------------------------

@tf.keras.utils.register_keras_serializable()   # <-- FIXED: Changed saving to utils
class L2Normalization(Layer):
    """Custom L2 normalization layer, safe for saving/loading and TFLite."""
    def call(self, inputs):
        return tf.math.l2_normalize(inputs, axis=1)

def build_embedding_model(embedding_dim=16, image_size=224):
    base_model = applications.MobileNetV3Large(
        input_shape=(image_size, image_size, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg'
    )

    base_model.trainable = False   # freeze backbone

    x = base_model.output
    x = layers.Dense(embedding_dim)(x)
    x = layers.BatchNormalization()(x)
    x = L2Normalization()(x)       # <-- NO LAMBDA ANYMORE

    model = models.Model(inputs=base_model.input, outputs=x)
    return model

embedding_model = build_embedding_model()
embedding_model.summary()


# -----------------------------
# 3. TRIPLET LOSS
# -----------------------------
def triplet_loss(y_true, y_pred):
    # y_pred shape: (batch*3, embedding_dim) => [A, P, N] flattened
    batch_size = BATCH_SIZE
    embedding_dim = EMBEDDING_DIM

    anchor = y_pred[0:batch_size]
    positive = y_pred[batch_size:batch_size*2]
    negative = y_pred[batch_size*2:batch_size*3]

    pos_dist = tf.reduce_sum(tf.square(anchor - positive), axis=1)
    neg_dist = tf.reduce_sum(tf.square(anchor - negative), axis=1)

    loss = tf.maximum(pos_dist - neg_dist + TRIPLET_LOSS_MARGIN, 0.0)
    return tf.reduce_mean(loss)


# -----------------------------
# 4. TRAINING LOOP
# -----------------------------
dataset = TripletFaceDataset(TRAIN_DATA_PATH, batch_size=BATCH_SIZE)
steps_per_epoch = len(dataset)

# Keras Functional model for triplets
anchor_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
positive_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
negative_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

anchor_embed = embedding_model(anchor_input)
positive_embed = embedding_model(positive_input)
negative_embed = embedding_model(negative_input)

merged_output = layers.Concatenate(axis=0)([anchor_embed, positive_embed, negative_embed])
triplet_model = models.Model(inputs=[anchor_input, positive_input, negative_input], outputs=merged_output)
triplet_model.compile(optimizer=optimizers.Adam(LEARNING_RATE), loss=triplet_loss)

# Train
triplet_model.fit(dataset, epochs=EPOCHS, steps_per_epoch=steps_per_epoch)
# Out:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_11        │ (None, 224, 224,  │          0 │ input_layer_22[0… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_11[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation_40[0]… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu_38[0][0]    │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation_40[0]… │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_39[0][0]    │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_40[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_41[0][0]    │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_42[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_43[0][0]    │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_44[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 1, 1, 72)  │          0 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 1, 1, 72)  │          0 │ re_lu_45[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_44[0][0],   │
# │ (Multiply)          │ 72)               │            │ multiply_16[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_46[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_47[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 1, 1, 120) │          0 │ re_lu_48[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_47[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_17[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_49[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_18         │ (None, 1, 1, 120) │          0 │ re_lu_51[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_50[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_18[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_41[0]… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_42[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_43[0]… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_44[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_45[0]… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_46[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_47[0]… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_48[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_49[0]… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_50[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_19         │ (None, 1, 1, 480) │          0 │ re_lu_52[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_50[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_19[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_51[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_52[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_20         │ (None, 1, 1, 672) │          0 │ re_lu_53[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_52[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_20[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_53[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_54[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_21[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_21         │ (None, 1, 1, 672) │          0 │ re_lu_54[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_54[0]… │
# │ (Multiply)          │                   │            │ multiply_21[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_55[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_56[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_22[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_22         │ (None, 1, 1, 960) │          0 │ re_lu_55[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_56[0]… │
# │ (Multiply)          │                   │            │ multiply_22[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_57[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_58[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_23[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_23         │ (None, 1, 1, 960) │          0 │ re_lu_56[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_58[0]… │
# │ (Multiply)          │                   │            │ multiply_23[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 960)       │          0 │ activation_59[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 16)        │     15,376 │ avg_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l2_normalization_2  │ (None, 16)        │          0 │ batch_normalizat… │
# │ (L2Normalization)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,011,792 (11.49 MB)
#  Trainable params: 15,408 (60.19 KB)
#  Non-trainable params: 2,996,384 (11.43 MB)
# Epoch 1/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - loss: 0.5245
# Epoch 2/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 0.3120
# Epoch 3/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - loss: 0.2084
# Epoch 4/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - loss: 0.1340
# Epoch 5/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - loss: 0.1015
# Epoch 6/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - loss: 0.0780
# Epoch 7/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - loss: 0.0476
# Epoch 8/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - loss: 0.0491

# %% [markdown]
# MOBILENETV3 SMALL

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, applications
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
import os
import random
from PIL import Image
from tensorflow.keras.layers import Layer # Moved this import to the top

# -----------------------------
# CONFIGURATION
# -----------------------------
EMBEDDING_DIM = 64
TRIPLET_LOSS_MARGIN = 0.5
IMAGE_SIZE = 224
BATCH_SIZE = 16
LEARNING_RATE = 1e-4
EPOCHS = 8
TRAIN_DATA_PATH = '/content/drive/MyDrive/Dataset/training/dataset'

# -----------------------------
# 1. DATASET: ONLINE TRIPLET GENERATOR
# -----------------------------
class TripletFaceDataset(tf.keras.utils.Sequence):
    """Generate Anchor-Positive-Negative triplets on the fly."""

    def __init__(self, root_dir, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, samples_per_epoch=1000, **kwargs):
        super().__init__(**kwargs)
        self.root_dir = root_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.samples_per_epoch = samples_per_epoch

        # Map identity -> image paths
        self.identities = []
        self.identity_to_paths = {}
        for person_name in os.listdir(root_dir):
            person_path = os.path.join(root_dir, person_name)
            if os.path.isdir(person_path):
                image_paths = [os.path.join(person_path, f)
                               for f in os.listdir(person_path)
                               if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                if len(image_paths) >= 2:
                    self.identities.append(person_name)
                    self.identity_to_paths[person_name] = image_paths

        if len(self.identities) < 2:
            raise ValueError("Need at least 2 identities with 2+ images each.")

    def __len__(self):
        return self.samples_per_epoch // self.batch_size

    def __getitem__(self, idx):
        anchors = []
        positives = []
        negatives = []

        for _ in range(self.batch_size):
            # Anchor identity
            identity_A = random.choice(self.identities)
            A_paths = self.identity_to_paths[identity_A]
            A_path, P_path = random.sample(A_paths, 2)

            # Negative identity
            identity_N = random.choice([i for i in self.identities if i != identity_A])
            N_paths = self.identity_to_paths[identity_N]
            N_path = random.choice(N_paths)

            # Load and preprocess images
            A_img = self.load_image(A_path)
            P_img = self.load_image(P_path)
            N_img = self.load_image(N_path)

            anchors.append(A_img)
            positives.append(P_img)
            negatives.append(N_img)

        return (np.array(anchors), np.array(positives), np.array(negatives)), np.zeros((self.batch_size,))

    def load_image(self, path):
        img = Image.open(path).convert('RGB').resize((self.image_size, self.image_size))
        img_array = np.array(img) / 255.0  # Normalize to [0,1]
        return img_array


# -----------------------------
# 2. BUILD EMBEDDING MODEL
# -----------------------------

@tf.keras.utils.register_keras_serializable()
class L2Normalization(Layer):
    """Custom L2 normalization layer, safe for saving/loading and TFLite."""
    def call(self, inputs):
        return tf.math.l2_normalize(inputs, axis=1)

def build_embedding_model(embedding_dim=64, image_size=224):
    base_model = applications.MobileNetV3Small(
        input_shape=(image_size, image_size, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg'
    )

    base_model.trainable = False   # freeze backbone

    x = base_model.output
    x = layers.Dense(embedding_dim)(x)
    x = layers.BatchNormalization()(x)
    x = L2Normalization()(x)

    model = models.Model(inputs=base_model.input, outputs=x)
    return model

embedding_model = build_embedding_model()
embedding_model.summary()


# -----------------------------
# 3. TRIPLET LOSS
# -----------------------------
def triplet_loss(y_true, y_pred):
    batch_size = BATCH_SIZE
    embedding_dim = EMBEDDING_DIM

    anchor = y_pred[0:batch_size]
    positive = y_pred[batch_size:batch_size*2]
    negative = y_pred[batch_size*2:batch_size*3]

    pos_dist = tf.reduce_sum(tf.square(anchor - positive), axis=1)
    neg_dist = tf.reduce_sum(tf.square(anchor - negative), axis=1)

    loss = tf.maximum(pos_dist - neg_dist + TRIPLET_LOSS_MARGIN, 0.0)
    return tf.reduce_mean(loss)


# -----------------------------
# 4. TRAINING LOOP
# -----------------------------
dataset = TripletFaceDataset(TRAIN_DATA_PATH, batch_size=BATCH_SIZE)
steps_per_epoch = len(dataset)

# Keras Functional model for triplets
anchor_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
positive_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
negative_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

anchor_embed = embedding_model(anchor_input)
positive_embed = embedding_model(positive_input)
negative_embed = embedding_model(negative_input)

merged_output = layers.Concatenate(axis=0)([anchor_embed, positive_embed, negative_embed])
triplet_model = models.Model(inputs=[anchor_input, positive_input, negative_input], outputs=merged_output)
triplet_model.compile(optimizer=optimizers.Adam(LEARNING_RATE), loss=triplet_loss)

# Train
triplet_model.fit(dataset, epochs=EPOCHS, steps_per_epoch=steps_per_epoch)
# Out:
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_33      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_15        │ (None, 224, 224,  │          0 │ input_layer_33[0… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_15[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_96       │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 113, 113,  │          0 │ activation_96[0]… │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 56, 56,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_85 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │          0 │ re_lu_85[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │        136 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │          0 │ expanded_conv_sq… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │        144 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 1, 1, 16)  │          0 │ expanded_conv_sq… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_86 (ReLU)     │ (None, 1, 1, 16)  │          0 │ add_42[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_42         │ (None, 1, 1, 16)  │          0 │ re_lu_86[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 56, 56,    │          0 │ re_lu_85[0][0],   │
# │ (Multiply)          │ 16)               │            │ multiply_42[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │        256 │ expanded_conv_sq… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 56, 56,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 56, 56,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_87 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 57, 57,    │          0 │ re_lu_87[0][0]    │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 28, 28,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_88 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │      1,728 │ re_lu_88[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 28, 28,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_89 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        792 │ re_lu_89[0][0]    │
# │ (DepthwiseConv2D)   │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 28, 28,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_90 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │      2,112 │ re_lu_90[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 28, 28,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 28, 28,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 28, 28,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_97       │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 31, 31,    │          0 │ activation_97[0]… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │      2,400 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 14, 14,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_98       │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │          0 │ activation_98[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      2,328 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │      2,400 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 1, 1, 96)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_91 (ReLU)     │ (None, 1, 1, 96)  │          0 │ add_43[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_43         │ (None, 1, 1, 96)  │          0 │ re_lu_91[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 14, 14,    │          0 │ activation_98[0]… │
# │ (Multiply)          │ 96)               │            │ multiply_43[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │      3,840 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 14, 14,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_99       │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │      6,000 │ activation_99[0]… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 14, 14,    │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_100      │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 240) │          0 │ activation_100[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 64)  │     15,424 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 64)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 240) │     15,600 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 1, 1, 240) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_92 (ReLU)     │ (None, 1, 1, 240) │          0 │ add_44[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_44         │ (None, 1, 1, 240) │          0 │ re_lu_92[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 14, 14,    │          0 │ activation_100[0… │
# │ (Multiply)          │ 240)              │            │ multiply_44[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 14, 14,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 14, 14,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_101      │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │      6,000 │ activation_101[0… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 14, 14,    │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_102      │ (None, 14, 14,    │          0 │ expanded_conv_5_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 240) │          0 │ activation_102[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 64)  │     15,424 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 64)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 240) │     15,600 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 1, 1, 240) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_93 (ReLU)     │ (None, 1, 1, 240) │          0 │ add_45[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_45         │ (None, 1, 1, 240) │          0 │ re_lu_93[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 14, 14,    │          0 │ activation_102[0… │
# │ (Multiply)          │ 240)              │            │ multiply_45[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 14, 14,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 14, 14,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_103      │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      3,000 │ activation_103[0… │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_104      │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 120) │          0 │ activation_104[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_6_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_6_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_6_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 1, 1, 120) │          0 │ expanded_conv_6_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_94 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_46[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_46         │ (None, 1, 1, 120) │          0 │ re_lu_94[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_sq… │ (None, 14, 14,    │          0 │ activation_104[0… │
# │ (Multiply)          │ 120)              │            │ multiply_46[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │      5,760 │ expanded_conv_6_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        192 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │      6,912 │ expanded_conv_6_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_105      │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      3,600 │ activation_105[0… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_106      │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 144) │          0 │ activation_106[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 40)  │      5,800 │ expanded_conv_7_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 40)  │          0 │ expanded_conv_7_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 1, 1, 144) │      5,904 │ expanded_conv_7_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 1, 1, 144) │          0 │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_95 (ReLU)     │ (None, 1, 1, 144) │          0 │ add_47[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_47         │ (None, 1, 1, 144) │          0 │ re_lu_95[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_sq… │ (None, 14, 14,    │          0 │ activation_106[0… │
# │ (Multiply)          │ 144)              │            │ multiply_47[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │      6,912 │ expanded_conv_7_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        192 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 48)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     13,824 │ expanded_conv_7_… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_107      │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 17, 17,    │          0 │ activation_107[0… │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      7,200 │ expanded_conv_8_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_108      │ (None, 7, 7, 288) │          0 │ expanded_conv_8_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 288) │          0 │ activation_108[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 72)  │     20,808 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 72)  │          0 │ expanded_conv_8_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 1, 1, 288) │     21,024 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, 1, 1, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_96 (ReLU)     │ (None, 1, 1, 288) │          0 │ add_48[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_48         │ (None, 1, 1, 288) │          0 │ re_lu_96[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_sq… │ (None, 7, 7, 288) │          0 │ activation_108[0… │
# │ (Multiply)          │                   │            │ multiply_48[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │     27,648 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_109      │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │     14,400 │ activation_109[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_110      │ (None, 7, 7, 576) │          0 │ expanded_conv_9_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 576) │          0 │ activation_110[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 144) │     83,088 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 144) │          0 │ expanded_conv_9_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 1, 1, 576) │     83,520 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, 1, 1, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_97 (ReLU)     │ (None, 1, 1, 576) │          0 │ add_49[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_49         │ (None, 1, 1, 576) │          0 │ re_lu_97[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_sq… │ (None, 7, 7, 576) │          0 │ activation_110[0… │
# │ (Multiply)          │                   │            │ multiply_49[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 7, 7, 96)  │        384 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 7, 7, 96)  │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_111      │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │     14,400 │ activation_111[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 7, 7, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_112      │ (None, 7, 7, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │          0 │ activation_112[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │     83,088 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │     83,520 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, 1, 1, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_98 (ReLU)     │ (None, 1, 1, 576) │          0 │ add_50[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_50         │ (None, 1, 1, 576) │          0 │ re_lu_98[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 7, 7, 576) │          0 │ activation_112[0… │
# │ (Multiply)          │                   │            │ multiply_50[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │     55,296 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 7, 7, 96)  │        384 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_a… │ (None, 7, 7, 96)  │          0 │ expanded_conv_9_… │
# │ (Add)               │                   │            │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 576) │     55,296 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 576) │      2,304 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_113      │ (None, 7, 7, 576) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 576)       │          0 │ activation_113[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 64)        │     36,928 │ avg_pool[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_23[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l2_normalization_5  │ (None, 64)        │          0 │ batch_normalizat… │
# │ (L2Normalization)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 976,304 (3.72 MB)
#  Trainable params: 37,056 (144.75 KB)
#  Non-trainable params: 939,248 (3.58 MB)
# Epoch 1/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - loss: 0.3637
# Epoch 2/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - loss: 0.2317
# Epoch 3/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - loss: 0.1207
# Epoch 4/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - loss: 0.0949
# Epoch 5/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - loss: 0.0742
# Epoch 6/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - loss: 0.1071
# Epoch 7/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - loss: 0.0680
# Epoch 8/8
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - loss: 0.0459

# %%
import os

# Base path
base_path = "/content/drive/MyDrive/Dataset"

# -----------------------------
# 1. Save entire model (architecture + weights)
# -----------------------------
embedding_model_path = os.path.join(base_path, "face_embedding_model.keras")  # Use .keras extension
try:
    embedding_model.save(embedding_model_path)
    print(f"Entire embedding model saved successfully to {embedding_model_path}")
except Exception as e:
    print(f"Error saving entire embedding model: {e}")

# -----------------------------
# 2. Save only weights
# -----------------------------
embedding_weights_path = os.path.join(base_path, "face_embedding.weights.h5")  # Must end with .weights.h5
try:
    embedding_model.save_weights(embedding_weights_path)
    print(f"Embedding model weights saved successfully to {embedding_weights_path}")
except Exception as e:
    print(f"Error saving embedding model weights: {e}")
# Out:
# Entire embedding model saved successfully to /content/drive/MyDrive/Dataset/face_embedding_model.keras
# Embedding model weights saved successfully to /content/drive/MyDrive/Dataset/face_embedding.weights.h5

# %%
import tensorflow as tf
import os
from tensorflow.keras.layers import Layer # Import Layer for custom class

# Base path
base_path = "/content/drive/MyDrive/Dataset"

# Path to saved embedding model
embedding_model_path = os.path.join(base_path, "face_embedding_model.keras")  # Must match saved file

# Re-define custom layer for loading
@tf.keras.utils.register_keras_serializable()
class L2Normalization(Layer):
    """Custom L2 normalization layer, safe for saving/loading and TFLite."""
    def call(self, inputs):
        return tf.math.l2_normalize(inputs, axis=1)

# Load the model
try:
    embedding_model = tf.keras.models.load_model(embedding_model_path)
    print("Embedding model loaded successfully.")
except Exception as e:
    print(f"Error loading embedding model: {e}")

# Set model to evaluation mode (not necessary in Keras, but good practice)
embedding_model.trainable = False
# Out:
# Embedding model loaded successfully.

# %%
embedding_model = tf.keras.models.load_model(embedding_model_path, safe_mode=False)
embedding_model.trainable = False

import tensorflow as tf
import numpy as np
import os
from PIL import Image
from sklearn.metrics.pairwise import euclidean_distances

IMAGE_SIZE = 224

def preprocess_image(img_path):
    """Load image and preprocess exactly like during training."""
    img = Image.open(img_path).convert("RGB")
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))

    img = np.array(img).astype("float32") / 255.0
    return np.expand_dims(img, axis=0)   # shape: (1, 224, 224, 3)

def get_single_embedding(keras_model, img_path):
    """Returns a 64-D embedding from the Keras embedding model."""
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"Image not found: {img_path}")

    x = preprocess_image(img_path)

    # Get embedding
    embedding = keras_model.predict(x)[0]  # shape: (64,)
    return embedding

def create_database(keras_model, dataset_path):
    print("\n[INFO] Creating face recognition database...")

    database = {}

    for person_name in os.listdir(dataset_path):
        person_path = os.path.join(dataset_path, person_name)

        # Ignore hidden/system folders
        if not os.path.isdir(person_path) or person_name.startswith('.'):
            continue

        image_paths = [
            os.path.join(person_path, f)
            for f in os.listdir(person_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ]

        if len(image_paths) == 0:
            continue

        print(f"\nProcessing: {person_name}")
        embeddings = []

        for img_path in image_paths:
            try:
                emb = get_single_embedding(keras_model, img_path)
                embeddings.append(emb)
            except Exception as e:
                print(f"  Skipped {img_path} → {e}")

        if len(embeddings) > 0:
            avg_embedding = np.mean(embeddings, axis=0)
            database[person_name] = avg_embedding
            print(f"  ✔ Added {person_name} ({len(embeddings)} images)")
        else:
            print(f"  ✖ No valid embeddings for {person_name}")

    print(f"\n[INFO] Database created: {len(database)} identities.")
    return database

def recognize_single_image(query_embed, database, threshold=1.7):
    best_match = "Unknown"
    min_distance = float("inf")

    for name, ref_embed in database.items():
        distance = euclidean_distances(
            query_embed.reshape(1, -1),
            ref_embed.reshape(1, -1)
        )[0][0]

        if distance < min_distance:
            min_distance = distance
            best_match = name

    if min_distance < threshold:
        return best_match, min_distance
    else:
        return "Unknown", min_distance

TRAIN_DATA_PATH = "/content/drive/MyDrive/Dataset/training/dataset"
QUERY_IMAGE_PATH = "/content/drive/MyDrive/Dataset/testing/Screenshot 2025-12-08 135312.png"
RECOGNITION_THRESHOLD = 1.7

# Load model
embedding_model = tf.keras.models.load_model(
    "/content/drive/MyDrive/Dataset/face_embedding_model.keras",
    safe_mode=False
)
embedding_model.trainable = False

# Create database
face_database = create_database(embedding_model, TRAIN_DATA_PATH)
people = list(face_database.keys())

# Compute query embedding
query_embedding = get_single_embedding(embedding_model, QUERY_IMAGE_PATH)

# Identify
identity, distance = recognize_single_image(
    query_embedding, face_database, threshold=RECOGNITION_THRESHOLD
)

print("\n==============================")
print(f"Query Image: {os.path.basename(QUERY_IMAGE_PATH)}")
print(f"Identity: {identity}")
print(f"Distance: {distance:.4f}")
print("==============================")
# Out:
# [INFO] Creating face recognition database...
#
# Processing: MrVinh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   ✔ Added MrVinh (2 images)
#
# Processing: MrThanh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#   ✔ Added MrThanh (4 images)
#
# Processing: MrNam
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   ✔ Added MrNam (11 images)
#
# Processing: MrDuc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   ✔ Added MrDuc (2 images)
#
# Processing: MrCan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#   ✔ Added MrCan (2 images)
#
# Processing: MrSon
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   ✔ Added MrSon (2 images)
#
# Processing: MrNghi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#   ✔ Added MrNghi (3 images)
#
# Processing: MrSheeraz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
#   ✔ Added MrSheeraz (20 images)
#
# [INFO] Database created: 8 identities.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# ==============================
# Query Image: Screenshot 2025-12-08 135312.png
# Identity: MrNam
# Distance: 0.7232
# ==============================

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Config
TRAIN_DATA_PATH = '/content/drive/MyDrive/Dataset/training/dataset'
IMAGE_SIZE = 224
EMBEDDING_DIM = embedding_model.output_shape[-1]  # 64
BATCH_SIZE = 16

# Prepare embeddings
people = [d for d in os.listdir(TRAIN_DATA_PATH) if os.path.isdir(os.path.join(TRAIN_DATA_PATH,d)) and not d.startswith('.')]
num_people = len(people)

X = []  # embeddings
y = []  # labels

for idx, person in enumerate(people):
    folder = os.path.join(TRAIN_DATA_PATH, person)
    for fname in os.listdir(folder):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            img_path = os.path.join(folder, fname)
            img = Image.open(img_path).convert('RGB').resize((IMAGE_SIZE, IMAGE_SIZE))
            arr = np.array(img)/255.0
            arr = np.expand_dims(arr, axis=0).astype(np.float32)
            emb = embedding_model.predict(arr)
            X.append(emb[0])
            y.append(idx)

X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.int32)

print("Embedding matrix:", X.shape)
print("Labels:", y.shape)

input_emb = tf.keras.Input(shape=(EMBEDDING_DIM,))
x = tf.keras.layers.Dense(64, activation='relu')(input_emb)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.3)(x)
output = tf.keras.layers.Dense(num_people, activation='softmax', dtype='float32')(x)

classifier_model = tf.keras.Model(inputs=input_emb, outputs=output)
classifier_model.compile(optimizer='adam',
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])

classifier_model.summary()
classifier_model.fit(X, y, epochs=50, batch_size=8, verbose=1)

# Input image (0..255)
input_image_raw = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), dtype=tf.float32, name="image_input_raw")

# Rescale to 0..1
x = tf.keras.layers.Rescaling(1./255.0)(input_image_raw)

# Embedding
embedding_output = embedding_model(x)

# L2 normalization
embedding_norm = tf.keras.layers.Lambda(lambda t: tf.math.l2_normalize(t, axis=1))(embedding_output)

# Identity prediction
identity_output = classifier_model(embedding_norm)

identity_model_final = tf.keras.Model(inputs=input_image_raw, outputs=identity_output)
identity_model_final.summary()

def predict_identity_raw(image_path, model, people):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    arr = tf.keras.preprocessing.image.img_to_array(img)
    arr = np.expand_dims(arr.astype(np.float32), axis=0)
    preds = model.predict(arr)
    idx = np.argmax(preds)
    return people[idx], float(preds[0][idx])

test_image = '/content/drive/MyDrive/Dataset/testing/PXL_20250609_141755633.jpg'
name, prob = predict_identity_raw(test_image, identity_model_final, people)
print("Predicted:", name, prob)

save_path = "/content/drive/MyDrive/Dataset/face_classifier.keras"
identity_model_final.save(save_path)
print("Saved classifier to:", save_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Embedding matrix: (46, 64)
# Labels: (46,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,936 (19.28 KB)
#  Trainable params: 4,808 (18.78 KB)
#  Non-trainable params: 128 (512.00 B)
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.1161 - loss: 2.3773
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2430 - loss: 1.9443
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4366 - loss: 1.5438
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4343 - loss: 1.5101
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6704 - loss: 1.1007
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7010 - loss: 0.9825
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6047 - loss: 1.1026
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7593 - loss: 0.8330
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7557 - loss: 0.7252
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9106 - loss: 0.4927
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7489 - loss: 0.6876
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9291 - loss: 0.4306
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9008 - loss: 0.4762
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8850 - loss: 0.5327
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9201 - loss: 0.6165
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8057 - loss: 0.5964
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9938 - loss: 0.3225
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8946 - loss: 0.4774
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9709 - loss: 0.2580
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8964 - loss: 0.3032
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9153 - loss: 0.3981
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9530 - loss: 0.2739
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9060 - loss: 0.5311
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9647 - loss: 0.2881
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9591 - loss: 0.2826
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9507 - loss: 0.2771
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9733 - loss: 0.3096
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.1586
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1908
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.2044
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9530 - loss: 0.2861
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.3230
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9566 - loss: 0.2991
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9700 - loss: 0.1637
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9709 - loss: 0.1845
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1510
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9432 - loss: 0.1727
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9760 - loss: 0.1361
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9239 - loss: 0.2366
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1819
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0928
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1037
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9709 - loss: 0.1335
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9647 - loss: 0.1726
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1443
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9938 - loss: 0.1752
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9798 - loss: 0.1532
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9530 - loss: 0.1163
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9798 - loss: 0.1002
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9653 - loss: 0.1979
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image_input_raw (InputLayer)    │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_23 (Functional)      │ (None, 64)             │       976,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional (Functional)         │ (None, 8)              │         4,936 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 981,240 (3.74 MB)
#  Trainable params: 4,808 (18.78 KB)
#  Non-trainable params: 976,432 (3.72 MB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted: MrSheeraz 0.748803436756134
# Saved classifier to: /content/drive/MyDrive/Dataset/face_classifier.keras

# %%
import os

def get_file_size_mb(path):
    if os.path.exists(path):
        size_bytes = os.path.getsize(path)
        size_mb = size_bytes / (1024 * 1024)
        print(f"✔ File size: {size_mb:.2f} MB")
    else:
        print(f"❌ File not found: {path}")

embedding_path = "/content/drive/MyDrive/Dataset/face_embedding_model.keras"
classifier_path = "/content/drive/MyDrive/Dataset/face_classifier.keras"

get_file_size_mb(embedding_path)
get_file_size_mb(classifier_path)
# Out:
# ✔ File size: 4.26 MB
# ✔ File size: 4.35 MB

# %% [markdown]
# **PRUNING + INT8 QUANTIZATION TFLITE**

# %%
import os
import tensorflow as tf
import numpy as np

# Assuming these variables are defined in your execution environment:
# embedding_model (MobileNetV3 backbone)
# classifier_model (64-D Linear head)
# people (list of identities)
# quannene_training_path (path to training dataset root)

# ==============================
# USER SETTINGS
# ==============================
BASE_PATH = "/content/drive/MyDrive/Dataset"
OUT_DIR = os.path.join(BASE_PATH, "tflite_int8_pruned_small")
os.makedirs(OUT_DIR, exist_ok=True)

# 💡 CHANGE 1: Increase sparsity for more aggressive size reduction.
# Target 75% zero weights across the model.
FINAL_SPARSITY = 0.5
FINETUNE_EPOCHS = 50
BATCH_SIZE = 16
IMG_SIZE = (224, 224)

# ==============================
# 1. PREPARE DATASET (Normalization Change)
# ==============================
def load_img(path, label):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)

    # 💡 CHANGE 2: Normalize to the [-1, 1] range.
    # This is standard practice for MobileNetV3 and improves INT8 quantization ranges.
    img = (img / 127.5) - 1.0

    return img, label

dataset_root = os.path.join(quannene_training_path, "dataset")
train_files, train_labels, val_files, val_labels = [], [], [], []

for label_idx, person in enumerate(people):
    pdir = os.path.join(dataset_root, person)
    files = sorted([os.path.join(pdir,f) for f in os.listdir(pdir)
                    if f.lower().endswith(('.jpg','.png','.jpeg'))])
    if len(files)==0: continue

    split = max(1, int(0.8*len(files)))
    train_files += files[:split]
    train_labels += [label_idx]*split

    val = files[split:]
    if len(val)==0:
        val = files[-1:]
    val_files += val
    val_labels += [label_idx]*len(val)

train_ds = tf.data.Dataset.from_tensor_slices((train_files, train_labels))
val_ds   = tf.data.Dataset.from_tensor_slices((val_files, val_labels))

train_ds = train_ds.map(load_img, num_parallel_calls=tf.data.AUTOTUNE)\
                   .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds   = val_ds.map(load_img, num_parallel_calls=tf.data.AUTOTUNE)\
                 .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print(f"[INFO] Train: {len(train_files)}  Val: {len(val_files)}")

# ==============================
# 2. AGGRESSIVE MANUAL PRUNING (Targets ALL Conv Kernels)
# ==============================
def manual_prune_all(model, final_sparsity):
    """Applies magnitude pruning across all 'kernel' weights in the model."""
    clone = tf.keras.models.clone_model(model)
    clone.set_weights(model.get_weights())

    all_weights, refs = [], []

    # 1. Collect all kernel weights (from embedding model and classifier)
    for li, layer in enumerate(clone.layers):
        for vi, w in enumerate(layer.weights):
            # Check for convolution or linear layer weights
            if "kernel" in w.name.lower() or "dense" in w.name.lower():
                wflat = w.numpy().flatten()
                all_weights.append(wflat)
                # refs store index, weight index, and original shape
                refs.append((li, vi, w.numpy().shape))

    if len(all_weights) == 0:
        print("[WARN] No kernel weights found for pruning.")
        return clone

    # 2. Determine global pruning threshold
    concat = np.concatenate(all_weights)
    k = int(final_sparsity * concat.size)
    thresh = np.sort(np.abs(concat))[k-1]

    # 3. Apply zeros based on threshold
    pos = 0
    for (li, vi, orig_shape), wflat in zip(refs, all_weights):
        n = wflat.size
        # Get the segment from the global concatenated weights
        seg = concat[pos:pos+n]

        # Prune: set values less than thresh to 0.0
        pruned = np.where(np.abs(seg) < thresh, 0.0, seg).reshape(orig_shape)

        # Update the layer weights
        layer = clone.layers[li]
        weights = layer.get_weights()
        weights[vi] = pruned
        layer.set_weights(weights)
        pos += n

    print(f"[INFO] Aggressive Manual Pruning applied (Sparsity: {final_sparsity*100:.0f}%)")
    return clone

# Prune the entire model (both embedding_model and classifier)
# ⚠️ This requires access to the full model, which the original code assumes is 'classifier_model'
# I assume your 'classifier_model' is the small head, and 'embedding_model' is the backbone.
# We will combine them for pruning and then reconstruct.

# Since we cannot easily combine and re-split for pruning, we will prune the embedding model and classifier separately:

pruned_embedding_model = manual_prune_all(embedding_model, FINAL_SPARSITY)
pruned_classifier = manual_prune_all(classifier_model, FINAL_SPARSITY)


# ==============================
# 3. BUILD FULL MODEL WITH PRUNED COMPONENTS
# ==============================
def build_full_pruned(FRmodel, classifier_model):
    # FRmodel is now the pruned embedding model
    FRmodel.trainable = False

    inp = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), dtype=tf.float32)

    # 💡 CHANGE 3: Remove Rescaling layer, as normalization is now done in load_img

    e = FRmodel(inp) # Pass input directly to the pruned embedding model
    if isinstance(e, dict):
        e = list(e.values())[0]
    if len(e.shape) > 2:
        e = tf.keras.layers.Flatten()(e)

    # Replace Lambda with serializable custom L2Norm
    # 💡 L2Norm can sometimes be tricky for quantization, but we keep it for now.
    e = tf.keras.layers.Lambda(lambda t: tf.math.l2_normalize(t, axis=1), name="l2norm")(e)

    out = classifier_model(e) # classifier_model is now the pruned classifier head
    return tf.keras.Model(inputs=inp, outputs=out, name="int8_pruned_model")

final_model = build_full_pruned(pruned_embedding_model, pruned_classifier)
final_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# ==============================
# 4. FINE-TUNE (Retraining the pruned weights)
# ==============================
print("[INFO] Fine-tuning aggressively pruned model...")
# Fine-tuning is critical to recover accuracy after pruning
final_model.fit(train_ds, validation_data=val_ds, epochs=FINETUNE_EPOCHS)
print("[INFO] Fine-tuning complete")

import os
import tensorflow as tf
import numpy as np
# ... (All previous imports)

# ... (Sections 1, 2, 3, 4 remain as in the previous aggressive pruning script) ...

# ==============================
# 5. INT8 FULL-INTEGER QUANTIZATION (Optimized for Minimum Size)
# ==============================
def representative_dataset():
    # Only need a few samples for the converter to calculate quantization ranges
    for f in train_files[:200]:
        img = tf.io.read_file(f)
        img = tf.io.decode_image(img, channels=3)
        img = tf.image.resize(img, IMG_SIZE)
        img = tf.cast(img, tf.float32)
        # Apply the same normalization as in load_img: [-1, 1]
        img = (img / 127.5) - 1.0
        img = tf.expand_dims(img,0)
        yield [img]

# --- CRITICAL CHANGE: Use INT8 Input/Output for smallest possible file size ---
converter = tf.lite.TFLiteConverter.from_keras_model(final_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

# ⚠️ FORCING INT8 INPUT/OUTPUT REDUCES FILE SIZE SIGNIFICANTLY
# This forces the final TFLite file to only contain INT8 tensors,
# which are 4x smaller than FLOAT32 weights.
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_int8 = converter.convert()
tflite_path = os.path.join(OUT_DIR, "identity_pruned_int8_smallest.tflite")

# --- Manual stripping of TFLite (Optional but helps) ---
# Forcing the full INT8 conversion usually takes care of the size,
# as the vast majority of the file is now 1-byte integers instead of 4-byte floats.

with open(tflite_path, "wb") as f:
    f.write(tflite_int8)

print("[SAVED] INT8 model ->", tflite_path)
final_size_mb = os.path.getsize(tflite_path) / (1024*1024)
print(f"[SIZE] Final TFLite size: {final_size_mb:.2f} MB")

# --- FINAL ANALYSIS ---
if final_size_mb <= 2.5:
    print("[SUCCESS] Target size achieved!")
else:
    print(f"[NOTE] Conversion complete. If the size is still > 2.5MB, the limiting factor is the dense complexity of the MobileNetV3 backbone.")

print("[DONE] Pipeline finished successfully.")
# Out:
# [INFO] Train: 33  Val: 13
# [INFO] Aggressive Manual Pruning applied (Sparsity: 50%)
# [INFO] Aggressive Manual Pruning applied (Sparsity: 50%)
# [INFO] Fine-tuning aggressively pruned model...
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.3596 - loss: 1.7823 - val_accuracy: 0.2308 - val_loss: 2.1159
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 899ms/step - accuracy: 0.3596 - loss: 1.7923 - val_accuracy: 0.2308 - val_loss: 2.1096
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 992ms/step - accuracy: 0.3596 - loss: 1.7874 - val_accuracy: 0.2308 - val_loss: 2.1035
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 902ms/step - accuracy: 0.3596 - loss: 1.8131 - val_accuracy: 0.2308 - val_loss: 2.0975
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.8062 - val_accuracy: 0.2308 - val_loss: 2.0917
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7901 - val_accuracy: 0.2308 - val_loss: 2.0860
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 955ms/step - accuracy: 0.3596 - loss: 1.7797 - val_accuracy: 0.2308 - val_loss: 2.0804
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 911ms/step - accuracy: 0.3596 - loss: 1.7899 - val_accuracy: 0.2308 - val_loss: 2.0749
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 896ms/step - accuracy: 0.3596 - loss: 1.7848 - val_accuracy: 0.2308 - val_loss: 2.0696
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.3596 - loss: 1.7805 - val_accuracy: 0.2308 - val_loss: 2.0644
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.3596 - loss: 1.7776 - val_accuracy: 0.2308 - val_loss: 2.0593
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 963ms/step - accuracy: 0.3596 - loss: 1.7742 - val_accuracy: 0.2308 - val_loss: 2.0544
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 842ms/step - accuracy: 0.3596 - loss: 1.7762 - val_accuracy: 0.2308 - val_loss: 2.0495
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 905ms/step - accuracy: 0.3596 - loss: 1.7628 - val_accuracy: 0.2308 - val_loss: 2.0448
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7878 - val_accuracy: 0.2308 - val_loss: 2.0401
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7738 - val_accuracy: 0.2308 - val_loss: 2.0355
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 934ms/step - accuracy: 0.3596 - loss: 1.7673 - val_accuracy: 0.2308 - val_loss: 2.0311
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 943ms/step - accuracy: 0.3596 - loss: 1.7821 - val_accuracy: 0.2308 - val_loss: 2.0267
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 951ms/step - accuracy: 0.3596 - loss: 1.7656 - val_accuracy: 0.2308 - val_loss: 2.0225
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 851ms/step - accuracy: 0.3596 - loss: 1.7716 - val_accuracy: 0.2308 - val_loss: 2.0183
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.3596 - loss: 1.7848 - val_accuracy: 0.2308 - val_loss: 2.0143
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7669 - val_accuracy: 0.2308 - val_loss: 2.0103
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 861ms/step - accuracy: 0.3596 - loss: 1.7552 - val_accuracy: 0.2308 - val_loss: 2.0065
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 851ms/step - accuracy: 0.3596 - loss: 1.7654 - val_accuracy: 0.2308 - val_loss: 2.0027
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 921ms/step - accuracy: 0.3596 - loss: 1.7622 - val_accuracy: 0.2308 - val_loss: 1.9990
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7500 - val_accuracy: 0.2308 - val_loss: 1.9955
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7611 - val_accuracy: 0.2308 - val_loss: 1.9920
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 969ms/step - accuracy: 0.3596 - loss: 1.7495 - val_accuracy: 0.2308 - val_loss: 1.9886
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 927ms/step - accuracy: 0.3596 - loss: 1.7424 - val_accuracy: 0.2308 - val_loss: 1.9853
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 948ms/step - accuracy: 0.3596 - loss: 1.7569 - val_accuracy: 0.2308 - val_loss: 1.9820
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 892ms/step - accuracy: 0.3596 - loss: 1.7649 - val_accuracy: 0.2308 - val_loss: 1.9789
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.3596 - loss: 1.7787 - val_accuracy: 0.2308 - val_loss: 1.9759
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 892ms/step - accuracy: 0.3596 - loss: 1.7551 - val_accuracy: 0.2308 - val_loss: 1.9730
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 860ms/step - accuracy: 0.3596 - loss: 1.7614 - val_accuracy: 0.2308 - val_loss: 1.9701
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 968ms/step - accuracy: 0.3596 - loss: 1.7586 - val_accuracy: 0.2308 - val_loss: 1.9672
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7318 - val_accuracy: 0.2308 - val_loss: 1.9644
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.3596 - loss: 1.7355 - val_accuracy: 0.2308 - val_loss: 1.9617
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 938ms/step - accuracy: 0.3596 - loss: 1.7431 - val_accuracy: 0.2308 - val_loss: 1.9591
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 923ms/step - accuracy: 0.3596 - loss: 1.7307 - val_accuracy: 0.2308 - val_loss: 1.9565
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 877ms/step - accuracy: 0.3596 - loss: 1.7602 - val_accuracy: 0.2308 - val_loss: 1.9540
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 887ms/step - accuracy: 0.3596 - loss: 1.7439 - val_accuracy: 0.2308 - val_loss: 1.9514
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.3596 - loss: 1.7238 - val_accuracy: 0.2308 - val_loss: 1.9490
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7627 - val_accuracy: 0.2308 - val_loss: 1.9467
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 915ms/step - accuracy: 0.3596 - loss: 1.7488 - val_accuracy: 0.2308 - val_loss: 1.9444
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 912ms/step - accuracy: 0.3596 - loss: 1.7415 - val_accuracy: 0.2308 - val_loss: 1.9422
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 888ms/step - accuracy: 0.3596 - loss: 1.7477 - val_accuracy: 0.2308 - val_loss: 1.9400
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7269 - val_accuracy: 0.2308 - val_loss: 1.9378
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.3596 - loss: 1.7433 - val_accuracy: 0.2308 - val_loss: 1.9356
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3596 - loss: 1.7568 - val_accuracy: 0.2308 - val_loss: 1.9335
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 910ms/step - accuracy: 0.3596 - loss: 1.7399 - val_accuracy: 0.2308 - val_loss: 1.9315
# [INFO] Fine-tuning complete
# Saved artifact at '/tmp/tmpnbc0e0gv'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_2226')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   132750695570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695574672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695564880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695563344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695569488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695565264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085352336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085351760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085354448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085353296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085354640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085353488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085352528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085354064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085352720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085352912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085351952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085353104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085354832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085351568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085348688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085351376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085352144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085354256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085349072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085351184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085348112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085349840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085349648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085347344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085348880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085350608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085347920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085345040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085347536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085349456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085349264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085345424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085347728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085348304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085347152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085342352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085343696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085346768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085345232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085348496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085342736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085342928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085344464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085344272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085343888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085345808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085345616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085343312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085344080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085344656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085342544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085343504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085339088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085340048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085340816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085344848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132750695565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085339664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085340624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085339472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085340240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085338896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085339280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085339856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085342160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085341968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100985168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085340432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751085338704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100969616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100983248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100982288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100983824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100977872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100971152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100982864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100980368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100982480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100983632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100976912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100977296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100983056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100983440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100980752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100984016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100974992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100976144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100979408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100982096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100981904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100975376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100980560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100980176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100974608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100978448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100976720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100973456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100974032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100977488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100979792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100978640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100975952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100975760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100978064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100976528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751100981328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226543696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226540816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226539472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226543888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226541584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226545232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226543312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226542928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226543504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226543120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226540624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226544656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226538128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226542736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226545040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226541776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226542160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226541968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226542352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226545424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226549264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226548688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226544464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226541200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226548112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226547536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226544848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226547152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226544272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226547728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226548304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226544080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226552144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226547344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226550224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226548880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226550992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226549072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226551184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226549648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226549840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226550416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226551376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226549456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132753987552656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132751226550608: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# [SAVED] INT8 model -> /content/drive/MyDrive/Dataset/tflite_int8_pruned_small/identity_pruned_int8_smallest.tflite
# [SIZE] Final TFLite size: 1.20 MB
# [SUCCESS] Target size achieved!
# [DONE] Pipeline finished successfully.
